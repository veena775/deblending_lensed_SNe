# %%
from astropy.io import fits
import matplotlib.pyplot as plt

# %%
# Open FITS file
hdul = fits.open('outputs/SNsims_TD_noise/image_Roman_g_146401_newSN56150.fits')

# scratch/network/vk9342/lenstronomy-tutorials/Notebooks/JP_spring_2025_modified_code/outputs/SNsims_TD_noise/image_LS4_g_146401_newSN_56150fits

# Print info about contents
hdul.info()

# Get data from the primary HDU (usually index 0)
data = hdul[0].data

# Display with matplotlib
plt.imshow(data, cmap='gray', origin='lower')
plt.colorbar()
plt.title('FITS Image')
plt.show()
# Out:
# Filename: outputs/SNsims_TD_noise/image_Roman_g_146401_newSN56150.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      21   (55, 55)   float64
