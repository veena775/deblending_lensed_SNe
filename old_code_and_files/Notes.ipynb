# %% [markdown]
# # JP Spring 2025

# %% [markdown]
# ## Feb 20th
# time delay cosmography - see a time delay between images of supernova so can see epochs <br>
# **lenstronomy - code overview:** <br>
# redshift of the lens (intermediate galaxy), redshift of source <br>
# pixel scale important - smaller pixels higher res - rubin about 0.2 arcsec pixels, Euclid has 0.11  <br>
# how well to resolve sources - also atmospheric smearing if on ground - around 0.7 arcsec, Euclid has non coz in space <br>
# psf - point source function - shape of a point source as it passes through the atm <br>
# Simulations: params for rubin and Euclid  <br>
#
# code block 3: <br>
# galaxy params <br>
# es are ellipticity - gaosim has good guide<br>
# theta_E angle of ellipse <br>
# is it in the center of image (usually yes) <br>
# shear - default for now<br>
# Sersic profile is typical galaxy shape for now default later replace w catalogue<br>
#
# same for source galaxy<br>
#
# then make image<br>
#
# then:<br>
# given this knowledge, what would the time delays<br>
#
# next step: we want to sim multiple epochs, not just one image<br>
# supernova light curves - cosmo code<br>
# SNcosmo<br>
#
#
# Rubin. -epochs - every. 3 days for 100 days<br>
#
# **For next week:** <br>
# run first part of time delay cosmology, run to create multiple images at different times using cosmo code light curve <br>
#
# get test images<br>
#
# galsim galaxy parameters<br>
# main goal show for a few realistic systems of interest here is what the Rubin and Euclid systems would look like, how well can we model Rubin w and without Euclid. <br>

# %% [markdown]
# ## Feb 28th
# notes in time delay cosm as comments

# %% [markdown]
# ## March 10th
#
# roman band, euclid w just one
#
# assume converting sn cosmo flux to mags
#
#
# time delay cosm
#
# encorporate time variable source modeling from simulating telescoped api
#
# https://arxiv.org/pdf/2311.17997 <br>
# fig 8
#
#
# once we have multiepoch images <br>
# deblending code to extract light curves
#
# then see how good the time delays are
#
# can we me mweasure time deleys percicely
#
# methods based paper
#
# use LSST
#
# one epoch at high respolution <br>
# multiple every three days ar low res

# %% [markdown]
# ## March 21st
#
# background of grav lensed supernovae
#
# why we want to use time delay cosm for H
#
# sims used by danny
#
# two diff surveay euclid and rubin
#
# maybe paper on how tehy extract time delays
#
# my work: <br>
# how I do sncosmo, lemstronomy sims <br>
# plot of unmagnified light curves <br>
#
# images for some diff systems based on redshifts and galaxy params what coresponding images look like in rubin and euclid
#
# then charlotte will run scarlotte 2 to extract light curves
#
# see how precicely we can measure time delays from thise light curves
#
# first key result is sims for a couple diff systems
#
# second conclusio, once simulated a bunch of systems wht time delays, angular separation can we measure precicely, and for which of those do we need spae based image and not just ground based
#
# overarching goal which systems can we extract time delays from

# %% [markdown]
# ## Mar 26th
#
# look at h5py format, explore and understand
#
# find galaies w similar redshifts and delays as in screenshot
#
# ru for those
#
# max time delays - find column
#
# his paper might describe them
#
# what are units of fluxes
#
#
# make images at multiple epochs
#
# how we pulled out the diff systems, what they look like at diff epochs
#
# where do we draw the line, at what angular separations do we draw the line
#
# run code that charlotte edited
#
# find systems that would be a good distributon of delays and generate those images
#
# script currently matches source and lens redshift, but should match by max time delay

# %% [markdown]
# ## Mar 31
#
# within 0.2 days
#
# calculate first for redshift
#
# max time delay
#
# if not then try first 1000
#
# dual and a quad for each 5 systems would be great
#
# run her py file to see if same error
#
# or look at lsst.py and define like ls4, but better if we use their function

# %% [markdown]
# ## April 7th
#
# Extract light curves from fits files
#
# Scarlet 2

# %% [markdown]
# ## April 11th
#
# extract magnified delayed (2 or 4) light curved look like
# hopefully built into lenstronomy
#
# or it tells me the time delays, might also have the magnification factor as a oaram I can extract - all I need is magnified factor and delay and initia sncosmo light curve
#
# scarlet2 in future work section

# %% [markdown]
# ## April 18th

# %% [markdown]
# ## April 25th
