# %%
import numpy as np
import astropy.units as u

# %%
m_p = 938 * u.MeV
m_pi0 = 135 * u.MeV
E_gamma = 10**(-3) * u.eV

# %%
((2 * m_p * m_pi0 + m_pi0**2)/ (4*E_gamma)).to(u.MeV)
# Out:
# <Quantity 6.787125e+13 MeV>
